# %%
import pandas as pd

# Replace 'file_path' with the actual path to your CSV file
file_path = '/Users/divi/workspace/Projects/healthcare_readmission/diabetic_original_data.csv'

# Load the CSV file into a pandas DataFrame
df = pd.read_csv(file_path)

# Display the first few rows of the DataFrame
df.head()
# Out:
#    encounter_id  patient_nbr             race  gender      age weight  \
# 0       2278392      8222157        Caucasian  Female   [0-10)      ?
# 1        149190     55629189        Caucasian  Female  [10-20)      ?
# 2         64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3        500364     82442376        Caucasian    Male  [30-40)      ?
# 4         16680     42519267        Caucasian    Male  [40-50)      ?
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# 1                  1                         1                    7
# 2                  1                         1                    7
# 3                  1                         1                    7
# 4                  1                         1                    7
#
#    time_in_hospital  ... citoglipton insulin  glyburide-metformin  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101766 entries, 0 to 101765
# Data columns (total 50 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   encounter_id              101766 non-null  int64
#  1   patient_nbr               101766 non-null  int64
#  2   race                      101766 non-null  object
#  3   gender                    101766 non-null  object
#  4   age                       101766 non-null  object
#  5   weight                    101766 non-null  object
#  6   admission_type_id         101766 non-null  int64
#  7   discharge_disposition_id  101766 non-null  int64
#  8   admission_source_id       101766 non-null  int64
#  9   time_in_hospital          101766 non-null  int64
#  10  payer_code                101766 non-null  object
#  11  medical_specialty         101766 non-null  object
#  12  num_lab_procedures        101766 non-null  int64
# ...

# %%
selected_columns = ['encounter_id','patient_nbr','race','gender','age','weight']  # Update with your desired column names
required_cols = ['encounter_id','patient_nbr','admission_type_id','discharge_disposition_id','admission_source_id','time_in_hospital','payer_code','medical_specialty','num_lab_procedures','num_procedures','num_medications','number_outpatient','number_emergency','number_inpatient','number_diagnoses','change','diabetesMed','readmitted'] 
# Create a new DataFrame with only the selected columns
demographics = df[selected_columns]
health = df[required_cols]
# Display the first few rows of the new DataFrame
demographics.head()
health.head()
# Out:
#    encounter_id  patient_nbr  admission_type_id  discharge_disposition_id  \
# 0       2278392      8222157                  6                        25
# 1        149190     55629189                  1                         1
# 2         64410     86047875                  1                         1
# 3        500364     82442376                  1                         1
# 4         16680     42519267                  1                         1
#
#    admission_source_id  time_in_hospital payer_code         medical_specialty  \
# 0                    1                 1          ?  Pediatrics-Endocrinology
# 1                    7                 3          ?                         ?
# 2                    7                 2          ?                         ?
# 3                    7                 2          ?                         ?
# 4                    7                 1          ?                         ?
#
# ...

# %%
demographics.head()
# Out:
#    encounter_id  patient_nbr             race  gender      age weight
# 0       2278392      8222157        Caucasian  Female   [0-10)      ?
# 1        149190     55629189        Caucasian  Female  [10-20)      ?
# 2         64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3        500364     82442376        Caucasian    Male  [30-40)      ?
# 4         16680     42519267        Caucasian    Male  [40-50)      ?

# %%
demographics.to_csv('demographics.csv', index=False)
print("CSV file has been created successfully.")

# %%
health.to_csv('patient_data.csv', index=False)
print("CSV file has been created successfully.")

# %%
health.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101766 entries, 0 to 101765
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   encounter_id              101766 non-null  int64
#  1   patient_nbr               101766 non-null  int64
#  2   admission_type_id         101766 non-null  int64
#  3   discharge_disposition_id  101766 non-null  int64
#  4   admission_source_id       101766 non-null  int64
#  5   time_in_hospital          101766 non-null  int64
#  6   payer_code                101766 non-null  object
#  7   medical_specialty         101766 non-null  object
#  8   num_lab_procedures        101766 non-null  int64
#  9   num_procedures            101766 non-null  int64
#  10  num_medications           101766 non-null  int64
#  11  number_outpatient         101766 non-null  int64
#  12  number_emergency          101766 non-null  int64
# ...
